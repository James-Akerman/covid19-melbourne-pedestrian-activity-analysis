# %%
# Set everything up
import json
import requests
from pprint import pprint 
api_key = ""

# %%
# Documentation
# https://www.developer.vic.gov.au/index.php?option=com_apiportal&view=apitester&usage=api&tab=tests&apiName=ABS+Labour+Force+API&apiId=2a59f1cd-d7f9-4d07-9d61-ad30c0e6bc8c&managerId=1&type=rest&apiVersion=1.0.0&menuId=153&renderTool=1#!/v1.0/GET_labour_force_statistics
# Example API request
api = "https://wovg-community.gateway.prod.api.vic.gov.au/abs/v1.0/labour-force-statistics?"
region = "VICTORIA"
data_item = "LABOUR_FORCE_FULL_TIME"
age = "15_AND_OVER"
start_period = "2019-08"
end_period = "2021-09"
api_key = "INSERT KEY HERE!"

url = api + "region=" + region + "&data_item=" + data_item + "&age=" + age + "&start_period=" + start_period + "&end_period=" + end_period

headers = {
    "Content-Type": "application/json",
    "Accept": "application/json",
    "apikey": api_key
}

response = requests.get(url, headers=headers).json()

# Print Response
pprint(req)
# Out:
# {'_links': [{'href': '/abs/v1.0/labour-force-statistics?age=15_AND_OVER&data_item=LABOUR_FORCE_FULL_TIME&end_period=2021-09&region=VICTORIA&start_period=2019-08&page=1&limit=1000',
#              'rel': 'self'},
#             {'href': '/abs/v1.0/labour-force-statistics?age=15_AND_OVER&data_item=LABOUR_FORCE_FULL_TIME&end_period=2021-09&region=VICTORIA&start_period=2019-08&page=1&limit=1000',
#              'rel': 'first'},
#             {'href': '/abs/v1.0/labour-force-statistics?age=15_AND_OVER&data_item=LABOUR_FORCE_FULL_TIME&end_period=2021-09&region=VICTORIA&start_period=2019-08&page=1&limit=1000',
#              'rel': 'last'}],
#  '_meta': {'count': 144,
#            'limit': 1000,
#            'page': 1,
#            'response_time': '0.405 seconds',
#            'response_time_ms': 405,
#            'total_records': 144},
#  'labour_force_statistics': [{'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2019-08',
#                               'observation_value': '1493.0021647',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2019-09',
#                               'observation_value': '1503.540826',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2019-10',
#                               'observation_value': '1522.426621',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2019-11',
#                               'observation_value': '1521.5166269',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2019-12',
#                               'observation_value': '1526.7789502',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-01',
#                               'observation_value': '1545.2901651',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-02',
#                               'observation_value': '1559.4337519',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-03',
#                               'observation_value': '1531.0350331',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-04',
#                               'observation_value': '1519.976605',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-05',
#                               'observation_value': '1520.4344203',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-06',
#                               'observation_value': '1515.3728665',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-07',
#                               'observation_value': '1502.7194807',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-08',
#                               'observation_value': '1485.1421775',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-09',
#                               'observation_value': '1471.8506026',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-10',
#                               'observation_value': '1514.3835296',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-11',
#                               'observation_value': '1534.4775729',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-12',
#                               'observation_value': '1544.089593',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-01',
#                               'observation_value': '1536.926564',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-02',
#                               'observation_value': '1551.9494677',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-03',
#                               'observation_value': '1535.049249',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-04',
#                               'observation_value': '1512.4616652',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-05',
#                               'observation_value': '1522.6444108',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-06',
#                               'observation_value': '1524.7287823',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-07',
#                               'observation_value': '1532.43189',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2019-08',
#                               'observation_value': '891.8697792',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2019-09',
#                               'observation_value': '881.6778415',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2019-10',
#                               'observation_value': '885.1670388',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2019-11',
#                               'observation_value': '896.2882647',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2019-12',
#                               'observation_value': '945.9951378',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-01',
#                               'observation_value': '923.7434631',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-02',
#                               'observation_value': '919.2038271',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-03',
#                               'observation_value': '895.9760306',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-04',
#                               'observation_value': '904.4199282',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-05',
#                               'observation_value': '915.3923418',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-06',
#                               'observation_value': '905.9736875',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-07',
#                               'observation_value': '885.9314477',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-08',
#                               'observation_value': '875.8325153',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-09',
#                               'observation_value': '874.3036097',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-10',
#                               'observation_value': '873.9782125',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-11',
#                               'observation_value': '901.8171233',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-12',
#                               'observation_value': '917.3957831',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-01',
#                               'observation_value': '930.6585848',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-02',
#                               'observation_value': '957.1053133',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-03',
#                               'observation_value': '930.866134',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-04',
#                               'observation_value': '923.7479143',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-05',
#                               'observation_value': '927.1108806',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-06',
#                               'observation_value': '901.432676',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-07',
#                               'observation_value': '915.8535368',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2019-08',
#                               'observation_value': '2384.8719439',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2019-09',
#                               'observation_value': '2385.2186675',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2019-10',
#                               'observation_value': '2407.5936598',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2019-11',
#                               'observation_value': '2417.8048916',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2019-12',
#                               'observation_value': '2472.774088',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-01',
#                               'observation_value': '2469.0336282',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-02',
#                               'observation_value': '2478.637579',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-03',
#                               'observation_value': '2427.0110637',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-04',
#                               'observation_value': '2424.3965332',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-05',
#                               'observation_value': '2435.8267621',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-06',
#                               'observation_value': '2421.346554',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-07',
#                               'observation_value': '2388.6509285',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-08',
#                               'observation_value': '2360.9746928',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-09',
#                               'observation_value': '2346.1542124',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-10',
#                               'observation_value': '2388.3617421',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-11',
#                               'observation_value': '2436.2946962',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-12',
#                               'observation_value': '2461.4853761',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-01',
#                               'observation_value': '2467.5851488',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-02',
#                               'observation_value': '2509.054781',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-03',
#                               'observation_value': '2465.915383',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-04',
#                               'observation_value': '2436.2095795',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-05',
#                               'observation_value': '2449.7552914',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-06',
#                               'observation_value': '2426.1614583',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-07',
#                               'observation_value': '2448.2854268',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2019-08',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2019-09',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2019-10',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2019-11',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2019-12',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-01',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-02',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-03',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-04',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-05',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-06',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-07',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-08',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-09',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-10',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-11',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Males'},
# ...
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-02',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-03',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-04',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-05',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-06',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-07',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Females'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2019-08',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2019-09',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2019-10',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2019-11',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2019-12',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-01',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-02',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-03',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-04',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-05',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-06',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-07',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-08',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-09',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-10',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-11',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2020-12',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-01',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-02',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-03',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-04',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-05',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-06',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Labour Force - full '
#                                                        "time ('000)",
#                               'observation_month': '2021-07',
#                               'observation_value': 'NaN',
#                               'region_description': 'Victoria',
#                               'sex_description': 'Persons'}]}
